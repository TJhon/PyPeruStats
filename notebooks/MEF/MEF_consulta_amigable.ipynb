# %%
from perustats.MEF import MEFScraper

# %% [markdown]
# # INGRESOS

# %%
# Steps para años 2009-2011
STEPS_INGRESO_2009_2011 = [
    dict(
        desc="Seleccionar total, click nivel de gobierno",
        select_row_text="total",
        click_bttn="nivel_gobierno",
    ),
    dict(
        desc="Seleccionar gob locales, click genérica",
        select_row_text="locales",
        click_bttn="generica",
    ),
    dict(
        name="estructura_generica",
        desc="Iterar estructuras de recaudacion, click departamento",
        select_row_text=None,  # None = loop
        click_bttn="departamento",
        save_group=True,
    ),
    dict(
        name="departamento",
        desc="Iterar departamentos, click municipalidad",
        select_row_text=None,
        click_bttn="municipalidad",
    ),
]

# Steps para años 2012-2026
STEPS_INGRESO_2012_2026 = [
    dict(
        desc="Seleccionar total, click nivel de gobierno",
        select_row_text="total",
        click_bttn="nivel_gobierno",
    ),
    dict(
        desc="Seleccionar gob locales, click sub tipo",
        select_row_text="locales",
        click_bttn="sub_tipo_gobierno",
    ),
    dict(
        desc="Seleccionar gob. municipales, click genérica",
        select_row_text="municipalidades",
        click_bttn="generica",
    ),
    dict(
        name="estructura_generica",
        desc="Iterar estructuras de recaudacion, click departamento",
        select_row_text=None,
        click_bttn="departamento",
        save_group=True,
    ),
    dict(
        name="departamento",
        desc="Iterar departamentos, click municipalidad",
        select_row_text=None,
        click_bttn="municipalidad",
    ),
]

# %%
scraper_ingresos = MEFScraper(
        tipo='ingreso',
        master_dir_save='./data/raw/temp/ingresos/'
    )


scraper_ingresos.run(year=2009, steps=STEPS_INGRESO_2009_2011)
# Out:
# ...
#   Configuración para INGRESO - Año 2009
# ...
#   URL: https://apps5.mineco.gob.pe/transparenciaingresos/Navegador/Navegar_4.aspx?y=2009
#   Columnas: codigo_grp, concepto_region, pia, pim, recaudado
#   Directorio de guardado: data\raw\temp\ingresos\2009
# Inicializando sesión...
# ✓ Sesión iniciada. Filas iniciales: 1
# Iniciando proceso de extracción...
# :    Step 1: Seleccionar total, click nivel de gobierno
# :      Step 2: Seleccionar gob locales, click genérica
# :        Step 3: estructura_generica
#         -> [1/8] estructura_generica: 1: IMPUESTOS Y CONTRIBUCIONES OBLIGATORIAS
#           -> [1/25] departamento: 01: AMAZONAS
#           -> [2/25] departamento: 02: ANCASH
#           -> [3/25] departamento: 03: APURIMAC
#           -> [4/25] departamento: 04: AREQUIPA
#           -> [5/25] departamento: 05: AYACUCHO
#           -> [6/25] departamento: 06: CAJAMARCA
#           -> [7/25] departamento: 07: PROVINCIA CONSTITUCIONAL DEL CALLAO
# ...

# %%
scraper_ingresos = MEFScraper(
        tipo='ingreso',
        master_dir_save='./data/raw/temp/ingresos/'
    )


scraper_ingresos.run(year=2019, steps=STEPS_INGRESO_2012_2026)
# Out:
# ...
#   Configuración para INGRESO - Año 2019
# ...
#   URL: https://apps5.mineco.gob.pe/transparenciaingresos/Navegador/Navegar_6.aspx?y=2019
#   Columnas: codigo_grp, concepto_region, pia, pim, recaudado
#   Directorio de guardado: data\raw\temp\ingresos\2019
# Inicializando sesión...
# ✓ Sesión iniciada. Filas iniciales: 1
# Iniciando proceso de extracción...
# :    Step 1: Seleccionar total, click nivel de gobierno
# :      Step 2: Seleccionar gob locales, click sub tipo
# :        Step 3: Seleccionar gob. municipales, click genérica
# :          Step 4: estructura_generica
#           -> [1/8] estructura_generica: 1: IMPUESTOS Y CONTRIBUCIONES OBLIGATORIAS
#             -> [1/25] departamento: 01: AMAZONAS
#             -> [2/25] departamento: 02: ANCASH
#             -> [3/25] departamento: 03: APURIMAC
#             -> [4/25] departamento: 04: AREQUIPA
#             -> [5/25] departamento: 05: AYACUCHO
#             -> [6/25] departamento: 06: CAJAMARCA
# ...

# %% [markdown]
# # Gastos

# %%
# Steps para años 2009-2011
STEPS_GASTO_2009_2011 = [
    dict(
        desc="Seleccionar total, click nivel de gobierno",
        select_row_text="total",
        click_bttn="nivel_gobierno",
    ),
    dict(
        desc="Seleccionar gob. locales, click función",
        select_row_text="locales",
        click_bttn="funcion",
    ),
    dict(
        name="funcion",
        desc="Iterar funciones, click departamento",
        select_row_text=None,
        click_bttn="departamento",
        save_group=True,
        # extras = {"txt_search": ""}
    ),
    dict(
        name="departamento",
        desc="Iterar departamentos, click municipalidad",
        select_row_text=None,
        click_bttn="municipalidad",
        extras = {"ctl00$CPH1$TxtSearch": ""}
    ),
]
# Steps para años 2012-2026
STEPS_GASTO_2012_2026 = [
    dict(
        desc="Seleccionar total, click nivel de gobierno",
        select_row_text="total",
        click_bttn="nivel_gobierno",
    ),
    dict(
        desc="Seleccionar gob. locales, click sub tipo",
        select_row_text="local",
        click_bttn="sub_tipo_gobierno",
    ),
    dict(
        desc="Seleccionar municipalidades, click función",
        select_row_text="municipal",
        click_bttn="funcion",
    ),
    dict(
        name="funcion",
        desc="Iterar funciones, click departamento",
        select_row_text=None,
        click_bttn="departamento",
        save_group=True,
    ),
    dict(
        name="departamento",
        desc="Iterar departamentos, click municipalidad",
        select_row_text=None,
        click_bttn="municipalidad",
    ),
]

# %%
# Steps para años 2009-2011
STEPS_GASTO_2009_2011 = [
    dict(
        desc="Seleccionar total, click nivel de gobierno",
        select_row_text="total",
        click_bttn="nivel_gobierno",
    ),
    # dict(
    #     desc="Seleccionar gob. locales, click función",
    #     select_row_text="locales",
    #     click_bttn="funcion",
    # ),
    dict(
        name="gasto_total",
        desc="seleccionar gob. locales, click departamento",
        select_row_text="locales",
        click_bttn="departamento",
        save_group=True,
        # extras = {"txt_search": ""}
    ),
    dict(
        name="departamento",
        desc="Iterar departamentos, click municipalidad",
        select_row_text=None,
        click_bttn="municipalidad",
        extras = {"ctl00$CPH1$TxtSearch": ""}
    ),
]
# Steps para años 2012-2026
STEPS_GASTO_2012_2026 = [
    dict(
        desc="Seleccionar total, click nivel de gobierno",
        select_row_text="total",
        click_bttn="nivel_gobierno",
    ),
    dict(
        desc="Seleccionar gob. locales, click sub tipo",
        select_row_text="local",
        click_bttn="sub_tipo_gobierno",
    ),
    dict(
        name ='gasto_total',
        desc="Seleccionar municipalidades, click función",
        select_row_text="municipal",
        click_bttn="departamento",
        save_group = True
    ),
    # dict(
    #     name="funcion",
    #     desc="Iterar funciones, click departamento",
    #     select_row_text=None,
    #     click_bttn="departamento",
    #     save_group=True,
    # ),
    dict(
        name="departamento",
        desc="Iterar departamentos, click municipalidad",
        select_row_text=None,
        click_bttn="municipalidad",
    ),
]

# %%
scraper_gastos = MEFScraper(
        tipo='gasto',
        master_dir_save=r"C:\Users\Jhon Flores\Dropbox\alcaldes_salarios\data\raw\siaf\gasto\totales"
    )

# %%
scraper_gastos.run(year=2010, steps=STEPS_GASTO_2009_2011)

# %%
for y in range(2012, 2026):
    scraper_gastos.run(year=y, steps=STEPS_GASTO_2012_2026)
# Out:
# ...
#   Configuración para GASTO - Año 2012
# ...
#   URL: https://apps5.mineco.gob.pe/transparencia/mensual/Navegar_5.aspx?y=2012&ap=ActProy
#   Columnas: codigo_grp, concepto_region, pia, pim, certificacion, compromiso_anual, atencion_de_compromiso_mensual, devengado, girado, avance_p
#   Directorio de guardado: C:\Users\Jhon Flores\Dropbox\alcaldes_salarios\data\raw\siaf\gasto\totales\2012
# Inicializando sesión...
# ✓ Sesión iniciada. Filas iniciales: 1
# Iniciando proceso de extracción...
# :    Step 1: Seleccionar total, click nivel de gobierno
# :      Step 2: Seleccionar gob. locales, click sub tipo
# :        Step 3: gasto_total
#           -> [1/25] departamento: 01: AMAZONAS
#           -> [2/25] departamento: 02: ANCASH
#           -> [3/25] departamento: 03: APURIMAC
#           -> [4/25] departamento: 04: AREQUIPA
#           -> [5/25] departamento: 05: AYACUCHO
#           -> [6/25] departamento: 06: CAJAMARCA
# ...
